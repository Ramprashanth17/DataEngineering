# %% [markdown]
# How to debug in the Databricks Notebooks

# %%
item_price = 120.00
tax_rate = 20
discount = 10.00

# Calculate tax
tax = item_price * tax_rate / 100

# Apply tax to the item_price
item_price_with_tax = item_price + tax

# Apply discount to the item_price_with_tax
final_price = item_price_with_tax - discount

print(f"Final price: {final_price:.2f}")
