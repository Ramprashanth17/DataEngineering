# %%
# %sql
select current_metastore();

# %% [markdown]
# Configure Access to Cloud Storage via UC
#
# Access Cloud Storage

# %%
# %fs ls 'abfss://demo@deacourseextdld.dfs.core.windows.net/'

# %% [markdown]
# CREATE EXTERNAL LOCATION

# %%
# %sql
create external location if not exists dea_course_ext_dl_demo
  url 'abfss://demo@deacourseextdld.dfs.core.windows.net/'
  with (storage credential dea_course_ext_sc)
  comment 'External location for Demo purposes;'
