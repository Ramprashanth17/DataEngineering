# %%
# Importing the modules
import pandas as pd

# %%
##** Opening csv files using Python **##
csv_file = pd.read_csv('./h9gi-nx95.csv')
csv_file.head(5)
# Out:
#                 crash_date crash_time   borough  zip_code  latitude  \
# 0  2021-09-11T00:00:00.000       2:39       NaN       NaN       NaN
# 1  2022-03-26T00:00:00.000      11:45       NaN       NaN       NaN
# 2  2023-11-01T00:00:00.000       1:29  BROOKLYN   11230.0  40.62179
# 3  2022-06-29T00:00:00.000       6:55       NaN       NaN       NaN
# 4  2022-09-21T00:00:00.000      13:21       NaN       NaN       NaN
#
#    longitude                       location           on_street_name  \
# 0        NaN                            NaN    WHITESTONE EXPRESSWAY
# 1        NaN                            NaN  QUEENSBORO BRIDGE UPPER
# 2 -73.970024  \n,  \n(40.62179, -73.970024)            OCEAN PARKWAY
# 3        NaN                            NaN       THROGS NECK BRIDGE
# 4        NaN                            NaN          BROOKLYN BRIDGE
#
#   off_street_name cross_street_name  ...  contributing_factor_vehicle_2  \
# ...

# %%
## Parquet file ##
"""Parquet stores data in its binary form and unlike csv files, which stores data by row, Parquet stores
data in the column level. Parquet vectorizes the data making it compatible to work with big-data settings as it lowers the computation time. Python uses "pyarrow" package to process parquet files"""

parquet_file = pd.read_parquet('yellow_tripdata_2022-01.parquet')
parquet_file.head(5)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2022-01-01 00:35:40   2022-01-01 00:53:29              2.0
# 1         1  2022-01-01 00:33:43   2022-01-01 00:42:07              1.0
# 2         2  2022-01-01 00:53:21   2022-01-01 01:02:19              1.0
# 3         2  2022-01-01 00:25:21   2022-01-01 00:35:23              1.0
# 4         2  2022-01-01 00:36:48   2022-01-01 01:14:20              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           3.80         1.0                  N           142           236
# 1           2.10         1.0                  N           236            42
# 2           0.97         1.0                  N           166           166
# 3           1.09         1.0                  N           114            68
# 4           4.30         1.0                  N            68           163
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
### Reading data from APIs ###
"""APIs are the go to plug and play datasources. However, since a 3rd party maintains the data you've
no control over the quality of data and the usage of data is usually tracked as well. We'll use
a python package called "certifi", which contains "Root certificates for validating the trustworthiness of SSL certificates, while verifying the identity of TLS hosts."""
"""The urllib3 Python library is a user-friendly HTTP client in Python that helps with some of the “under the hood” processes of retrying requests and dealing with HTTP redirects"""

# Import API-related Python modules
import json
import certifi
import urllib3
from urllib3 import request

url = 'https://data.cityofnewyork.us/resource/h9gi-nx95.json?$limit=500'
http = urllib3.PoolManager(cert_reqs = 'CERT_REQUIRED', ca_certs = certifi.where())
# Check the status of API to retrieve the data
api_status = http.request('GET', url).status
print(api_status)
if api_status == 200:
    ##Create a pool manager that can be used to read the API response
    """Pool manager is a request method that handles connection pooling, i.e., each consecutive
    time the connection is requested, Pool Manager reuses the original connection
    in cached memory. It's important when web requests are limited."""
    data = json.loads(http.request('GET', url).data.decode('utf-8'))
    df_api = pd.json_normalize(data)
else:
    df_api = pd.DataFrame()
df_api.head(5)
# Out:
# 200
#                 crash_date crash_time           on_street_name  \
# 0  2021-09-11T00:00:00.000       2:39    WHITESTONE EXPRESSWAY
# 1  2022-03-26T00:00:00.000      11:45  QUEENSBORO BRIDGE UPPER
# 2  2023-11-01T00:00:00.000       1:29            OCEAN PARKWAY
# 3  2022-06-29T00:00:00.000       6:55       THROGS NECK BRIDGE
# 4  2022-09-21T00:00:00.000      13:21          BROOKLYN BRIDGE
#
#   off_street_name number_of_persons_injured number_of_persons_killed  \
# 0       20 AVENUE                         2                        0
# 1             NaN                         1                        0
# 2        AVENUE K                         1                        0
# 3             NaN                         0                        0
# 4             NaN                         0                        0
#
#   number_of_pedestrians_injured number_of_pedestrians_killed  \
# 0                             0                            0
# ...

# %%
## From sql Databases sqlite
import sqlite3
with sqlite3.connect("movies.sqlite") as conn:
    sql_df = pd.read_sql("SELECT * FROM movies", conn)
sql_df.head()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\PycharmProjects\ETLpipelineswithPython\.venv\Lib\site-packages\pandas\io\sql.py:2664, in SQLiteDatabase.execute(self, sql, params)
#    2663 try:
# -> 2664     cur.execute(sql, *args)
#    2665     return cur
#
# OperationalError: no such table: movies
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[8], line 4
#       2 import sqlite3
#       3 with sqlite3.connect("movies.sqlite") as conn:
# ----> 4     sql_df = pd.read_sql("SELECT * FROM movies", conn)
#       5 sql_df.head()
#
# File ~\PycharmProjects\ETLpipelineswithPython\.venv\Lib\site-packages\pandas\io\sql.py:708, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
# ...

# %%
## Reading data from websites, webscraping

df_html = pd.read_html('https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)',match = 'by country')
#Let's see the no.of tables present in the html file with the tag "by country"
print(len(df_html))
# The first table
df_html[0]
# Out:
# 4
#     Country/Territory IMF[1][12]            World Bank[13]             \
#     Country/Territory   Forecast       Year       Estimate       Year
# 0               World  113795678       2025      111326370       2024
# 1       United States   30507217       2025       29184890       2024
# 2               China   19231705  [n 1]2025       18743803  [n 3]2024
# 3             Germany    4744804       2025        4659929       2024
# 4               India    4187017       2025        3912686       2024
# ..                ...        ...        ...            ...        ...
# 217          Kiribati        312       2025            308       2024
# 218  Marshall Islands        297       2025            280       2024
# 219             Nauru        169       2025            160       2024
# 220        Montserrat          —          —              —          —
# 221            Tuvalu         65       2025             62       2023
#
#     United Nations[14]
# ...
